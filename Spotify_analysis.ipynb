# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\spotify_ds\tracks.csv")

# %%
data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %% [markdown]
# # Data cleaning

# %%
#check row wise and find duplicate rows
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, popularity, duration_ms, explicit, artists, id_artists, release_date, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
data.isnull().sum()       #find null values
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
sns.heatmap(data.isnull())   #show in hit-map format
# Out:
# <AxesSubplot:>

# %%
data[data['name'].isin(['Save Your Tears'])]       #show particular  element in column
# Out:
#                             id             name  popularity  duration_ms  \
# 92810   5QO79kh1waicV47BqGRL3g  Save Your Tears          97       215627
# 382050  2ExKb6Ag2WXob6FpkSeXhE  Save Your Tears          67       215627
#
#         explicit         artists                  id_artists release_date  \
# 92810          1  ['The Weeknd']  ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-03-20
# 382050         1  ['The Weeknd']  ['1Xyo4u8uXC1ZmMpatF05PJ']   2020-04-03
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 92810          0.680   0.826    0    -5.487     1       0.0309        0.0212
# 382050         0.684   0.817    0    -5.499     1       0.0308        0.0222
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 92810           0.000012     0.543    0.644  118.051               4
# 382050          0.000022     0.439    0.623  118.061               4

# %%
data.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
#create new column named release with datetime format
data["release"]= pd.to_datetime(data["release_date"])
data.info
# Out:
# <bound method DataFrame.info of                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
data.dtypes
# Out:
# id                          object
# name                        object
# popularity                   int64
# duration_ms                  int64
# explicit                     int64
# artists                     object
# id_artists                  object
# release_date                object
# danceability               float64
# energy                     float64
# key                          int64
# loudness                   float64
# mode                         int64
# speechiness                float64
# acousticness               float64
# instrumentalness           float64
# liveness                   float64
# valence                    float64
# tempo                      float64
# time_signature               int64
# release             datetime64[ns]
# dtype: object

# %% [markdown]
# # In which year highest number of songs were released ?

# %%
#occurance of individual years
data["release"].dt.year.value_counts()
# Out:
# 2020    13937
# 1998    12485
# 1999    12484
# 1997    12349
# 1996    12058
#         ...
# 1925      903
# 1923      657
# 1924      633
# 1922      294
# 1900        1
# Name: release, Length: 101, dtype: int64

# %%
data["release"].dt.year.value_counts().head(40).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#occurance of individual years
data["release"].dt.year.value_counts()
# Out:
# 2020    13937
# 1998    12485
# 1999    12484
# 1997    12349
# 1996    12058
#         ...
# 1925      903
# 1923      657
# 1924      633
# 1922      294
# 1900        1
# Name: release, Length: 101, dtype: int64

# %%
data.sort_values(by="release",ascending= False).head(10)
# Out:
#                             id                   name  popularity  \
# 93919   6cjSDzbazK0wsWWbZMRxsl  Blow Your Mind (Mwah)           0
# 188952  6b3AippDKmNU9ZpYv1u9L4                   Rojo           0
# 188868  1YTswXgjPiwAIQIMlCWsZV                  Negro           0
# 188867  1WEMrMUauyF2FgoOfyAIDb                Machika           0
# 188866  1T01S75AMk2nXp2ExJA8tl                  Negro           0
# 188865  1OZgkgzRuKafaGXlrtVFVh                 Morado           0
# 188864  1OOUyI2vvPGHfiLYvlASnm             LA CANCIÓN           0
# 188863  1NCLXNEEpUtSV8eS7me71G              Tu Verdad           0
# 188862  1HnmAoomeqIYBWAY6mL8tI                  Negro           0
# 188861  1GHG7eoxQi2vBedlDIFtS2      Sigo Extrañándote           0
#
#         duration_ms  explicit                         artists  \
# 93919        178583         0                    ['Dua Lipa']
# 188952       151147         0                    ['J Balvin']
# ...

# %% [markdown]
# # Maximum releases of artist

# %%
data.groupby('artists').artists.count()
# Out:
# artists
# ["'In The Heights' Original Broadway Company", 'Mandy Gonzalez']    1
# ["'Om' Alec Khaoli & Umoja"]                                        1
# ["'T Hof Van Commerce", 'TLP']                                      1
# ["'T Hof Van Commerce"]                                             6
# ["'Til Tuesday"]                                                    8
#                                                                    ..
# ['장정우']                                                             2
# ['조정현']                                                             1
# ['지선']                                                              2
# ['지수']                                                              1
# ['최진희']                                                             1
# Name: artists, Length: 114030, dtype: int64

# %% [markdown]
# # showing all the songs of Eminem released in year 2000

# %%
data.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
#
#   release_date  danceability  energy  ...  loudness  mode  speechiness  \
# 0   1922-02-22         0.645   0.445  ...   -13.338     1        0.451
# 1   1922-06-01         0.695   0.263  ...   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1
#
#      release
# 0 1922-02-22
# 1 1922-06-01
#
# ...

# %%
data['Year']=data['release'].dt.year #creating new column Year

# %%
data.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
data[(data['Year'] == 2000) & (data['artists'] == "['Eminem']")]['name']
# Out:
# 73442    The Real Slim Shady
# 73504           The Way I Am
# 73542               Kill You
# 73834               Criminal
# 73840               I'm Back
# 73876       Marshall Mathers
# 74012            Drug Ballad
# 74080               Who Knew
# 74142                    Kim
# Name: name, dtype: object

# %% [markdown]
# # Different rating of popularity defined by spotify and highest rated song

# %%
data.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
#
#   release_date  danceability  energy  ...  mode  speechiness  acousticness  \
# 0   1922-02-22         0.645   0.445  ...     1        0.451         0.674
# 1   1922-06-01         0.695   0.263  ...     1        0.957         0.797
#
#    instrumentalness  liveness  valence    tempo  time_signature    release  \
# 0             0.744     0.151    0.127  104.851               3 1922-02-22
# 1             0.000     0.148    0.655  102.009               1 1922-06-01
#
#    Year
# 0  1922
# 1  1922
#
# [2 rows x 22 columns]

# %%
data['popularity'].nunique()
# Out:
# 101

# %%
data['popularity'].unique()
# Out:
# array([  6,   0,   1,   4,  41,  38,  30,  28,  27,  26,  25,  23,  22,
#         20,  18,  17,  16,  15,  14,  11,  10,   8,   9,   5,   7,   2,
#         39,  33,  32,  24,  21,  19,  13,  12,   3,  51,  48,  40,  34,
#         29,  47,  43,  37,  35,  31,  55,  50,  36,  42,  65,  53,  45,
#         49,  46,  44,  52,  56,  54,  61,  62,  57,  69,  58,  68,  60,
#         64,  63,  67,  66,  59,  74,  71,  77,  70,  79,  75,  73,  72,
#         80,  78,  76,  82,  83,  84,  81,  86,  85,  87,  90,  88,  89,
#         94,  92,  97,  96,  95,  93,  91, 100,  99,  98], dtype=int64)

# %%
rate = data['popularity'].unique()
max(rate)
# Out:
# 100

# %%
data[data['popularity'] == 100]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
#
#                                               id_artists release_date  \
# 93802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   2021-03-19
#
#        danceability  energy  ...  mode  speechiness  acousticness  \
# 93802         0.677   0.696  ...     1        0.119         0.321
#
#        instrumentalness  liveness  valence  tempo  time_signature    release  \
# 93802               0.0      0.42    0.464  90.03               4 2021-03-19
#
#        Year
# 93802  2021
#
# [1 rows x 22 columns]

# %% [markdown]
# # change of duration from ms to min

# %%
data['duration'] = data['duration_ms'].apply(lambda x:(round(x/1000))/60) #change duration into min from ms
data.drop('duration_ms',inplace=True,axis=1)

# %%
data.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
#    danceability  energy  key  ...  speechiness  acousticness  \
# ...

# %%
data['duration'].max()
# Out:
# 93.68333333333334

# %%
data['duration'].min()
# Out:
# 0.05

# %%
data['duration'].mean()
# Out:
# 3.8341775302041756
